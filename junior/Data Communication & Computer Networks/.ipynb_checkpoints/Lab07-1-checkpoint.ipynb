# %%
import urllib
from sigproc import Signal,start_notebook
bkp = start_notebook()

urllib.request.urlretrieve("https://www.cpe.ku.ac.th/~cpj/204325/q7-1/q7-1-55.wav","q7-1-55.wav")
s = Signal(wav_file="q7-1-55.wav")
s.plot_time()
s.plot_freq(fig_options=dict(x_range=(100,1200),height=200))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="606bbfc4-88f1-439a-956a-afe7ffa2ab8d">Loading BokehJS ...</span>
#     </div>
# Notebook session ready.
#   <div class="bk-root" id="7fbb16cc-a52b-4db0-ad5d-f3f48760f10e"></div>
#   <div class="bk-root" id="ccd0c403-9501-4c2b-b47d-f7c50edbce33"></div>

# %%
ch2 = s.copy().filter((200,400))
ch2.plot_freq(fig_options=dict(x_range=(0,500),height=200))
ch2.plot_time(fig_options=dict(height=200))
# Out:
#   <div class="bk-root" id="d8022221-204a-4268-bfc5-a2fcabe06bb9"></div>
#   <div class="bk-root" id="48b541d8-c754-4f25-b434-552f2ad3c5ef"></div>

# %%
freq = 300
from numpy import sin,cos,pi
carrier_i = Signal(duration=ch2.duration,func=lambda t:sin(2*pi*freq*t))
carrier_q = Signal(duration=ch2.duration,func=lambda t:cos(2*pi*freq*t))
baseband_i = (ch2*carrier_i*2).filter(freq)
baseband_q = (ch2*carrier_q*2).filter(freq)
print("Baseband I")
baseband_i.plot_time(fig_options=dict(height=200))
print("Baseband Q")
baseband_q.plot_time(fig_options=dict(height=200))
# Out:
# Baseband I
# /home/ayumiizz/datacom/sigproc/sigproc.py:378: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ts.loc[interval,"a"] = func(ts[interval].t.as_matrix()-offset)
#   <div class="bk-root" id="6d9e274d-a974-447b-acf8-b41576ae164a"></div>
# Baseband Q
#   <div class="bk-root" id="773ffc78-a3c7-45e4-a64f-a3f57dc79241"></div>

# %%
for freq in [300,600,900]:
    ch2 = s.copy().filter((freq-100,freq+100))
#     ch2.plot_freq(fig_options=dict(x_range=(freq-200,freq+200),height=200))
#     ch2.plot_time(fig_options=dict(height=200))
    from numpy import sin,cos,pi
    carrier_i = Signal(duration=ch2.duration,func=lambda t:sin(2*pi*freq*t))
    carrier_q = Signal(duration=ch2.duration,func=lambda t:cos(2*pi*freq*t))
    baseband_i = (ch2*carrier_i*2).filter(freq)
    baseband_q = (ch2*carrier_q*2).filter(freq)
    print("Baseband I: " + str(freq))
    baseband_i.plot_time(fig_options=dict(height=200))
    print("Baseband Q: " + str(freq))
    baseband_q.plot_time(fig_options=dict(height=200))
# Out:
#   <div class="bk-root" id="c5085ff0-78d7-4634-a003-c1d7ec7bad9d"></div>
#   <div class="bk-root" id="303ca36c-f581-4ae5-bfe6-90b2899f3f99"></div>
# /home/ayumiizz/datacom/sigproc/sigproc.py:378: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ts.loc[interval,"a"] = func(ts[interval].t.as_matrix()-offset)
# Baseband I: 300
#   <div class="bk-root" id="4e89f2b8-0813-4b35-8dd1-7c2fc3a57fb6"></div>
# Baseband Q: 300
#   <div class="bk-root" id="42d49cc4-6a61-4e90-a0bf-dbb1766e7fad"></div>
#   <div class="bk-root" id="d5adee82-08ee-43d7-916f-6d9f5142a4cd"></div>
#   <div class="bk-root" id="47c6ffd1-2d3c-4d1e-b801-eeed8e1c3a62"></div>
# Baseband I: 600
#   <div class="bk-root" id="98912c71-94ef-468f-99d8-d116910a4210"></div>
# Baseband Q: 600
#   <div class="bk-root" id="6316a3f8-25d7-4862-a166-71ea4a72e161"></div>
#   <div class="bk-root" id="4ccd42f8-c30b-4813-a429-544edffe7eb5"></div>
#   <div class="bk-root" id="a421e97f-3e87-44fa-8ff5-2bab48585129"></div>
# Baseband I: 900
#   <div class="bk-root" id="a3659278-f400-448b-a255-a271e3b225be"></div>
# Baseband Q: 900
#   <div class="bk-root" id="93ede837-0d18-4db9-8d36-0e6bb42afb10"></div>
