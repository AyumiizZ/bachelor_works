# %%
import urllib
from sigproc import Signal,start_notebook
from bokeh.models import Span
start_notebook()

urllib.request.urlretrieve("https://www.cpe.ku.ac.th/~cpj/204325/q5-2/q5-2-51.wav","q5-2-51.wav")
s = Signal(wav_file="q5-2-51.wav")
s.plot_time()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b8b44184-2713-49f2-bdb1-c6475ae74e2b">Loading BokehJS ...</span>
#     </div>
# Notebook session ready.
#   <div class="bk-root" id="4b954561-3b03-4537-b960-c564a2b45f93"></div>
