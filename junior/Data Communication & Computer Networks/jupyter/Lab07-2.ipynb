# %%
import urllib
import numpy as np
from sigproc import Signal,start_notebook
from sigproc.digital import encode
bkp = start_notebook()

urllib.request.urlretrieve("https://www.cpe.ku.ac.th/~cpj/204325/q7-2/q7-2-55.wav","q7-2-55.wav")
s = Signal(wav_file="q7-2-55.wav")
s.plot_time()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9c0aceaa-0c4c-4113-9727-805f23ec71b2">Loading BokehJS ...</span>
#     </div>
# Notebook session ready.
#   <div class="bk-root" id="adb99c4f-2ff7-4280-a6f6-0ed111402bf9"></div>

# %%
t = np.arange(0,150,10)/1000

# %%
sig_nrz = encode("nrz",100,"01110 00111 00000")
sig_nrz.plot_time()
sig_nrz.plot_freq()
# Out:
#   <div class="bk-root" id="a99f86cd-b91e-4c90-9d3b-c56e58efabed"></div>
#   <div class="bk-root" id="3e39bc05-9c03-45e1-9b4b-6ac239abe707"></div>

# %%
sig_rz = encode("rz",300,"11111111111")
sig_rz.plot_time()
sig_rz.plot_freq()
# Out:
#   <div class="bk-root" id="1ee071de-09ee-4bf4-8efe-3f0fa819a4e0"></div>
#   <div class="bk-root" id="e2e90ab9-57dc-4bd1-8c4a-3c8637416929"></div>
