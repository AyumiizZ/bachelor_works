# %% [markdown]
# # OFDM Example
# โน้ตบุ๊คนี้เตรียมโค้ดอย่างง่ายเพื่อเป็นตัวอย่างให้เห็นถึงสัญญาณที่มีความถี่ orthogonal กัน (orthogonal frequency) ซึ่งเป็นกลไกสำคัญที่นำมาใช้ในกระบวนการ Orthognal Frequency Multiplexing (OFDM)

# %%
from numpy import sin,cos,pi
from sigproc import Signal,start_notebook,DEFAULT_PLOT_SETTINGS
from sigproc.analog import Qam

bkp = start_notebook()
DEFAULT_PLOT_SETTINGS['time_freq_fig_options']['height'] = 200
DEFAULT_PLOT_SETTINGS['freq_fig_options']['x_range'] = (0,1000)
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1ec0b02d-8ec0-449e-8109-a50b9b072204">Loading BokehJS ...</span>
#     </div>
# Notebook session ready.

# %% [markdown]
# ## สร้างมอดูเลเตอร์และมอดูเลทข้อมูล 2 ชุด

# %%
CONSTELLATION = {
    '0' : (0.3,0), 
    '1' : (0.3,180) 
}
BAUD = 10
FC1 = 500
FC2 = 600
data1 = '0100000000000000'
data2 = '0100000000000000'

# print("Data stream #1")
qam1 = Qam(CONSTELLATION,bitrate=BAUD*1,fc=FC1)
sig1 = qam1.generate_signal(data1)
sig1.plot_time_and_freq()

# print("Data stream #2")
qam2 = Qam(CONSTELLATION,bitrate=BAUD*1,fc=FC2)
sig2 = qam2.generate_signal(data2)
sig2.plot_time_and_freq()
# Out:
# /home/ayumiizz/datacom/act7-multiplex/sigproc/sigproc.py:378: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ts.loc[interval,"a"] = func(ts[interval].t.as_matrix()-offset)
#   <div class="bk-root" id="06651baf-1613-4b6c-b074-9c5681216af4"></div>
#   <div class="bk-root" id="a3a908e8-6551-4adc-aae1-f38aa78d836a"></div>

# %% [markdown]
# ## คำถามชวนคิด
# * หากใช้กระบวนการ FDM ปกติ ข้อมูลทั้งสองชุดสามารถถูกมอดูเลทให้ความถี่ใกล้กันได้มากที่สุดเท่าใด (อย่าลืมคำนึงถึง guard band ด้วย)?
